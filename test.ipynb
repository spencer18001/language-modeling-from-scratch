# %%
BYTE_TOKENS = tuple(bytes([i]) for i in range(256))
token = tuple(BYTE_TOKENS[b] for b in "test".encode("utf-8"))
token
# Out:
# (b't', b'e', b's', b't')

# %%
[i for i in range(1, 3)]
# Out:
# [1, 2]

# %%
3 // 2
# Out:
# 1
